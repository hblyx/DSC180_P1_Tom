# %%
import src.common_neighbor_community as cnc
import src.random_graph as rg
import networkx as nx
import numpy as np
import pandas as pd

r_seed = 123

# %load_ext autoreload
# %autoreload 2

# %%
RG = rg.RandomCommunitiesGraph()
G, actual_com = RG.generate_random_com_graph(N=150,
                                            n_groups=3,
                                            p_in_group=0.3,
                                            p_out_group=0.01,
                                            seed=r_seed)

RG.draw(seed=r_seed)

# %%
CNC = cnc.CommonNeighborCommunity(G, actual_com)
# Out:
# Reset all predictions

# %%
CNC.findAllCommunities(thres=0.1, weighted=True)
# Out:
# Reset all predictions
# Made predictions for all nodes

# %%
re = CNC.getResult()
re
# Out:
#      node  pred_com  actual_com
# 0       0         0           0
# 1       1         0           0
# 2       2         0           0
# 3       3         0           0
# 4       4         0           0
# ..    ...       ...         ...
# 145   123         2           2
# 146   124         2           2
# 147   125         2           2
# 148   126         2           2
# 149   127         2           2
#
# [150 rows x 3 columns]

# %%
RG = rg.RandomCommunitiesGraph()
G, actual_com = RG.generate_random_com_graph(N=150,
                                            n_groups=3,
                                            p_in_group=0.1,
                                            p_out_group=0.07,
                                            seed=r_seed)

RG.draw(seed=r_seed)

# %%
CNC = cnc.CommonNeighborCommunity(G, actual_com)
# Out:
# Reset all predictions

# %%
CNC.findAllCommunities(thres=0.1, weighted=True)
# Out:
# Reset all predictions
# Made predictions for all nodes
