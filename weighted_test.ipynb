# %%
import src.common_neighbor_community as cnc
import src.random_graph as rg
import networkx as nx

r_seed = 123

# %load_ext autoreload
# %autoreload 2

# %%
RG = rg.RandomCommunitiesGraph()
G, actual_com = RG.generate_random_com_graph(N=150,
                                              n_groups=3,
                                              p_in_group=0.1,
                                              p_out_group=0.01,
                                              seed=r_seed)

RG.draw(seed=r_seed)

# %%
cnc.CommonNeighborCommunity(G, 0.5, actual_com, weighted=True)
