# %%
import sys
sys.path.append('..')

import networkx as nx

from src.features import graph_statistics as stats
from collections import defaultdict

r_seed = 123

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load dataset

# %%
G = nx.read_gml("../data/raw/polblogs.gml")
print("Number of nodes:", G.order())
print("Number of edges:", G.size())

actual_com = defaultdict(int)
for i in G.nodes:
    com = G.nodes[i]["value"]
    actual_com[i] = com
    
actual = [actual_com[i] for i in actual_com]
# Out:
# Number of nodes: 1490
# Number of edges: 19090

# %%
S = stats.GraphStats(G, actual_com)
S.draw(seed=r_seed)

# %%
df = S.getCommunityStats()
df.head()
# Out:
# Average in-group probability: 0.0315
# Average out-group probability: 0.003
#    number_of_nodes  in_group_degree  in_group_probability  out_group_degree  \
# 0              758            16816              0.029306              1688
# 1              732            17988              0.033617              1688
#
#    out_group_probability
# 0               0.003042
# 1               0.003042
